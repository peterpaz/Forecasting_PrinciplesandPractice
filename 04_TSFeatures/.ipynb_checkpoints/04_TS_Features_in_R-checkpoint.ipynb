# %% [markdown]
# # INSTALLATION OF PACKAGES

# %%
install.packages('fpp3', dependencies = TRUE)
library(fpp3)
install.packages("tidyverse")
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# ── Attaching packages ──────────────────────────────────────────── fpp3 0.4.0 ──
#
# ✔ tibble      3.1.2      ✔ tsibble     1.0.1
# ✔ dplyr       1.0.6      ✔ tsibbledata 0.3.0
# ✔ tidyr       1.1.3      ✔ feasts      0.2.1
# ✔ lubridate   1.7.10     ✔ fable       0.3.1
# ✔ ggplot2     3.3.3
#
# ── Conflicts ───────────────────────────────────────────────── fpp3_conflicts ──
# ✖ lubridate::date()    masks base::date()
# ✖ dplyr::filter()      masks stats::filter()
# ✖ tsibble::intersect() masks base::intersect()
# ✖ tsibble::interval()  masks lubridate::interval()
# ✖ dplyr::lag()         masks stats::lag()
# ✖ tsibble::setdiff()   masks base::setdiff()
# ✖ tsibble::union()     masks base::union()
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
install.packages("feasts")
# examples: autocorrelation, box-cox transformation, numerical summary statistics, etc
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %% [markdown]
# # 1. Some simple Statistics

# %%
tourism[1:5,]
# Out:
#   Quarter Region   State           Purpose  Trips
# 1 1998 Q1 Adelaide South Australia Business 135.0777
# 2 1998 Q2 Adelaide South Australia Business 109.9873
# 3 1998 Q3 Adelaide South Australia Business 166.0347
# 4 1998 Q4 Adelaide South Australia Business 127.1605
# 5 1999 Q1 Adelaide South Australia Business 137.4485

# %%
tourism %>%
 features(Trips,list(mean=mean)) %>%
arrange(mean)
# Out:
#     Region                    State              Purpose  mean
# 1   Kangaroo Island           South Australia    Other    0.3403467
# 2   MacDonnell                Northern Territory Other    0.4490043
# 3   Wilderness West           Tasmania           Other    0.4782684
# 4   Barkly                    Northern Territory Other    0.6323856
# 5   Clare Valley              South Australia    Other    0.8977490
# 6   Barossa                   South Australia    Other    1.0215210
# 7   Kakadu Arnhem             Northern Territory Other    1.0426531
# 8   Lasseter                  Northern Territory Other    1.1357961
# 9   Wimmera                   Victoria           Other    1.1462369
# 10  MacDonnell                Northern Territory Visiting 1.1753932
# 11  Lasseter                  Northern Territory Visiting 1.3339982
# 12  East Coast                Tasmania           Other    1.3418344
# 13  Adelaide Hills            South Australia    Other    1.4049307
# ...

# %%
tourism %>% features(Trips, quantile)
# Out:
#     Region                     State              Purpose  0%
# 1   Adelaide                   South Australia    Business  68.7253928
# 2   Adelaide                   South Australia    Holiday  108.0330401
# 3   Adelaide                   South Australia    Other     25.9018459
# 4   Adelaide                   South Australia    Visiting 136.6111544
# 5   Adelaide Hills             South Australia    Business   0.0000000
# 6   Adelaide Hills             South Australia    Holiday    0.0000000
# 7   Adelaide Hills             South Australia    Other      0.0000000
# 8   Adelaide Hills             South Australia    Visiting   0.7776381
# 9   Alice Springs              Northern Territory Business   1.0084255
# 10  Alice Springs              Northern Territory Holiday    2.8085551
# 11  Alice Springs              Northern Territory Other      0.0000000
# 12  Alice Springs              Northern Territory Visiting   0.2081892
# ...

# %% [markdown]
# # 2. ACF Features

# %%
tourism %>% features(Trips,feat_acf)
# Out:
#     Region                     State              Purpose  acf1
# 1   Adelaide                   South Australia    Business  0.033270698
# 2   Adelaide                   South Australia    Holiday   0.045569980
# 3   Adelaide                   South Australia    Other     0.516805734
# 4   Adelaide                   South Australia    Visiting  0.068365364
# 5   Adelaide Hills             South Australia    Business  0.070914982
# 6   Adelaide Hills             South Australia    Holiday   0.131319990
# 7   Adelaide Hills             South Australia    Other     0.261142556
# 8   Adelaide Hills             South Australia    Visiting  0.139166739
# 9   Alice Springs              Northern Territory Business  0.217424370
# 10  Alice Springs              Northern Territory Holiday  -0.006604511
# 11  Alice Springs              Northern Territory Other     0.050923123
# 12  Alice Springs              Northern Territory Visiting -0.119573121
# ...

# %% [markdown]
# - first autocorrelation coefficient from the original data;
# - sum of squares of the first ten autocorrelation coefficients from the original data;
# - first autocorrelation coefficient from the differenced data;
# - sum of squares of the first ten autocorrelation coefficients from the differenced data;
# - first autocorrelation coefficient from the twice differenced data;
# - sum of squares of the first ten autocorrelation coefficients from the twice differenced data;
# - For seasonal data, the autocorrelation coefficient at the first seasonal lag is also returned.

# %% [markdown]
# # 3. STL Features

# %%
tourism %>%
  features(Trips, feat_stl)
# Out:
#     Region                     State              Purpose  trend_strength
# 1   Adelaide                   South Australia    Business 0.4514189
# 2   Adelaide                   South Australia    Holiday  0.5411193
# 3   Adelaide                   South Australia    Other    0.7427272
# 4   Adelaide                   South Australia    Visiting 0.4332942
# 5   Adelaide Hills             South Australia    Business 0.4534935
# 6   Adelaide Hills             South Australia    Holiday  0.5115746
# 7   Adelaide Hills             South Australia    Other    0.5841891
# 8   Adelaide Hills             South Australia    Visiting 0.4809335
# 9   Alice Springs              Northern Territory Business 0.5255087
# 10  Alice Springs              Northern Territory Holiday  0.3770119
# 11  Alice Springs              Northern Territory Other    0.4050490
# 12  Alice Springs              Northern Territory Visiting 0.2929873
# 13  Australia's Coral Coast    Western Australia  Business 0.5388835
# ...

# %% [markdown]
# These measures can be useful, for example,
# when you have a large collection of time series,
# and you need to find the series with the most trend or the most seasonality

# %%
tourism %>%
 features(Trips,feat_stl) %>%
 ggplot(aes(x=trend_strength, y=seasonal_strength_year,
            col= Purpose))+
 geom_point() +
 facet_wrap(vars(State)) # obs: es vars not var
# Seasonal strength vs trend strength for all tourism series.
# Out:
# plot without title

# %% [markdown]
# - Holiday series are most seasonal which is unsurprising.
# - The strongest trends tend to be in Western Australia and Victoria.

# %%
tourism %>%
 features(Trips,feat_stl) %>%
 filter(
  seasonal_strength_year == max(seasonal_strength_year) 
 ) %>%
 left_join(tourism, by =c("State","Region","Purpose")) %>%

 ggplot(aes(x=Quarter, y=Trips)) +
 geom_line() +
 facet_grid(vars(State,Region, Purpose))

# dont forget always %>% after filter.
# Out:
# plot without title

# %% [markdown]
# - This is the most seasonal series.

# %% [markdown]
# # 4. Exploring Australian tourism data

# %%
tourism[1:5,]
# Out:
#   Quarter Region   State           Purpose  Trips
# 1 1998 Q1 Adelaide South Australia Business 135.0777
# 2 1998 Q2 Adelaide South Australia Business 109.9873
# 3 1998 Q3 Adelaide South Australia Business 166.0347
# 4 1998 Q4 Adelaide South Australia Business 127.1605
# 5 1999 Q1 Adelaide South Australia Business 137.4485

# %%
tourism_features <- tourism %>%
 features(Trips, feature_set(pkgs="feasts"))
# Out:
# Warning message:
# “`n_flat_spots()` was deprecated in feasts 0.1.5.
# Please use `longest_flat_spot()` instead.
# This warning is displayed once every 8 hours.
# Call `lifecycle::last_warnings()` to see where this warning was generated.”
# Warning message:
# “304 errors (1 unique) encountered for feature 20
# [304] The `fracdiff` package must be installed to use this functionality. It can be installed with install.packages("fracdiff")
# ”

# %%
tourism_features
# Out:
#     Region                     State              Purpose  trend_strength
# 1   Adelaide                   South Australia    Business 0.4514189
# 2   Adelaide                   South Australia    Holiday  0.5411193
# 3   Adelaide                   South Australia    Other    0.7427272
# 4   Adelaide                   South Australia    Visiting 0.4332942
# 5   Adelaide Hills             South Australia    Business 0.4534935
# 6   Adelaide Hills             South Australia    Holiday  0.5115746
# 7   Adelaide Hills             South Australia    Other    0.5841891
# 8   Adelaide Hills             South Australia    Visiting 0.4809335
# 9   Alice Springs              Northern Territory Business 0.5255087
# 10  Alice Springs              Northern Territory Holiday  0.3770119
# 11  Alice Springs              Northern Territory Other    0.4050490
# 12  Alice Springs              Northern Territory Visiting 0.2929873
# 13  Australia's Coral Coast    Western Australia  Business 0.5388835
# ...

# %%
library(glue)
tourism_features %>%
  select_at(vars(contains("season"), Purpose)) %>%
  mutate(
    seasonal_peak_year = seasonal_peak_year +
      4*(seasonal_peak_year==0),
    seasonal_trough_year = seasonal_trough_year +
      4*(seasonal_trough_year==0),
    seasonal_peak_year = glue("Q{seasonal_peak_year}"),
    seasonal_trough_year = glue("Q{seasonal_trough_year}"),
  ) %>%
  GGally::ggpairs(mapping = aes(colour = Purpose))
# Out:
# Attaching package: ‘glue’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     collapse
#
#
# Registered S3 method overwritten by 'GGally':
#   method from
#   +.gg   ggplot2
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
tourism_features[1:5,]
# Out:
#   Region         State           Purpose  trend_strength seasonal_strength_year
# 1 Adelaide       South Australia Business 0.4514189      0.3799257
# 2 Adelaide       South Australia Holiday  0.5411193      0.6012834
# 3 Adelaide       South Australia Other    0.7427272      0.1889520
# 4 Adelaide       South Australia Visiting 0.4332942      0.4461801
# 5 Adelaide Hills South Australia Business 0.4534935      0.1399051
#   seasonal_peak_year seasonal_trough_year spikiness   linearity  curvature ⋯
# 1 3                  1                    161.5979905 -5.5126416 71.398378 ⋯
# 2 1                  3                      9.9512719 48.8854982 78.153633 ⋯
# 3 2                  1                      2.2814973 94.9853815 43.437378 ⋯
# 4 1                  3                     60.0653035 34.8778291 71.131626 ⋯
# 5 3                  1                      0.1177351  0.9436701 -3.299208 ⋯
#   shift_level_max shift_level_index shift_var_max shift_var_index shift_kl_max
# ...

# %%
library(broom)
pcs <- tourism_features %>%
  select(-State, -Region, -Purpose) %>%
  prcomp(scale = TRUE) %>%
  augment(tourism_features)
pcs %>%
  ggplot(aes(x = .fittedPC1, y = .fittedPC2, col = Purpose)) +
  geom_point() +
  theme(aspect.ratio = 1)
# Out:
# plot without title

# %%
outliers <- pcs %>%
  filter(.fittedPC1 > 10) %>%
  select(Region, State, Purpose, .fittedPC1, .fittedPC2)
outliers
# Out:
#   Region                 State             Purpose  .fittedPC1 .fittedPC2
# 1 Australia's North West Western Australia Business 11.26782   -13.136644
# 2 Australia's South West Western Australia Holiday  10.87224    -0.751541
# 3 Great Ocean Road       Victoria          Holiday  10.22332     6.972914
# 4 Melbourne              Victoria          Holiday  10.35268   -12.141376
# 5 South Coast            New South Wales   Holiday  13.30411     7.211747

# %%
outliers %>%
  left_join(tourism, by = c("State", "Region", "Purpose")) %>%
  mutate(
    Series = glue("{State}", "{Region}", "{Purpose}",
                  .sep = "\n\n")
  ) %>%
  ggplot(aes(x = Quarter, y = Trips)) +
  geom_line() +
  facet_grid(Series ~ ., scales = "free") +
  labs(title = "Outlying time series in PC space")
# Out:
# plot without title
